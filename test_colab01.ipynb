# %% [markdown]
# <a href="https://colab.research.google.com/github/oganiler/google_colab/blob/main/test_colab01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **This is my title**
#
# regular text
#
#
# ```
# # This is formatted as code
# ```
